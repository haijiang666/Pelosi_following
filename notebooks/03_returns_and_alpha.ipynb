# %% [markdown]
# # 03 — 收益与 Alpha

# %%
import pandas as pd
from pathlib import Path

ROOT = Path('..').resolve()
df = pd.read_csv(ROOT / 'reports/trades_analysis.csv', parse_dates=['transaction_date','disclosure_date'])
df['reveal_lag_days'].describe()

# %%
pd.read_parquet(ROOT / 'data/processed/event_study.parquet').groupby('event_window_day')['abnormal_return'].mean()

# %%
bt = pd.read_parquet(ROOT / 'data/processed/backtest.parquet')
bt.groupby('disclosure_date')['net_return'].mean().cumsum().plot()
