# %% [markdown]
# # 01 — 下载与 Cross-Check
#
# OGE 278-T 股票/ETF 披露（不含债券）。

# %%
import json
from pathlib import Path
import pandas as pd

ROOT = Path('..').resolve()
pd.read_csv(ROOT / 'data/processed/manifest.csv')

# %%
xcheck = json.loads((ROOT / 'reports/cross_check_manifest.json').read_text())
xcheck

# %%
pd.DataFrame(json.loads((ROOT / 'reports/web_cross_check.json').read_text()))
