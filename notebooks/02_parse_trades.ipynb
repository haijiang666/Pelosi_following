# %% [markdown]
# # 02 — 解析股票交易

# %%
import pandas as pd
from pathlib import Path

ROOT = Path('..').resolve()
trades = pd.read_parquet(ROOT / 'data/processed/trades.parquet')
trades.head(10)

# %%
trades.groupby('action').size()

# %%
trades[trades.asset_name.str.contains('DELL', case=False, na=False)]
